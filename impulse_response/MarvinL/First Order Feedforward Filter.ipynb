# %% [markdown]
# ## Laboratory Experiment 006: First Order FeedForward Filter
# # Marvin D. Llames
# # BSCPE 3-1-2025-2026
#
# Let's analyze the impulse response of a 1st order feedforward filter.

# %%
pip install SciencePlots
# Out:
# Collecting SciencePlots
#   Downloading scienceplots-2.2.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: matplotlib in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from SciencePlots) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from python-dateutil>=2.7->matplotlib->SciencePlots) (1.17.0)
# Downloading scienceplots-2.2.0-py3-none-any.whl (30 kB)
# Installing collected packages: SciencePlots
# Successfully installed SciencePlots-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import scienceplots
import numpy as np
import matplotlib.pyplot as plt

# If the line below is giving you compiler errors, comment it out.
plt.style.use(['science', 'notebook', 'grid'])

frameSize = 2048

def feedForwardFilter(x, a0, a1):
    y = np.zeros(x.size)
    for n in range(0, x.size):
        y[n] = a0 * x[n] + a1 * x[n-1]
    return y


impulse = np.zeros(frameSize)
impulse[0] = 1;

impulseResponse = feedForwardFilter(impulse, 0.5, 0.5)

fig, axes = plt.subplots(1, 2, figsize=(12,4))
ax = axes[0]
ax.plot(impulse, 'bo-')
ax.set_xlabel('Sample count')
ax.set_ylabel('Amplitude')
ax.set_ylim(-0.1, 1.1)
ax.set_xlim(-0.5, 10)
ax.set_title("Impulse")

ax = axes[1]
ax.plot(impulseResponse, 'ro-')
ax.set_xlabel('Sample count')
ax.set_ylim(-1.1, 1.1)
ax.set_xlim(-0.5, 11)
ax.set_title("Impulse Response")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We can then perform a Fourier transform on the impulse signal. This will give us an array of complex numbers which is stored in `spectrum`. Extracting the magnitudes of the complex numbers and plotting them will give us a frequency response plot, and extracting the angles will give us a phase response plot

# %%
from scipy.fftpack import fft

spectrum = fft(feedForwardFilter(impulse, 0.5, 0.5))

x = np.linspace(0, 0.5, spectrum.size//2)

fig, axes = plt.subplots(1, 2, figsize=(12,4))
ax = axes[0]
with np.errstate(divide='ignore'):
    y = (20 * np.log10(np.abs(spectrum)))[:spectrum.size//2]
ax.plot(x, y, 'b')
ax.set_xlabel('Normalized frequency')
ax.set_ylabel('Amplitude (dB)')
ax.set_title("Frequency Response")

ax = axes[1]
y = np.degrees(np.angle(spectrum))[:spectrum.size//2]
ax.plot(x, y, 'r')
ax.set_xlabel('Normalized frequency')
ax.set_ylabel('Phase (deg)')
ax.set_title("Phase Response")

plt.show()
