# %% [markdown]
# ## Laboratory Experiment 006: Impulse signal
# # Marvin D. Llames
# # BSCPE 3-1-2025-2026
# An impulse signal is made up of a single sample value of 1 in an infinitely long stream of zeros. You can think about it as a burst of energy, which arrives very quickly, and which dissipates just as quickly.

# %% [markdown]
# Let's see how we can visualize the impulse signal and generate one. But first, let's pull in some required dependencies

# %%
conda install -c conda-forge pandoc
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\marvin\anaconda3\envs\DSP11-CPE3A
#
#   added / updated specs:
#     - pandoc
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.11.12 |       h4c7d964_0         149 KB  conda-forge
#     certifi-2025.11.12         |     pyhd8ed1ab_0         153 KB  conda-forge
#     openssl-3.6.0              |       h725018a_0         9.0 MB  conda-forge
#     pandoc-3.8.3               |       h57928b3_0        25.5 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        34.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandoc             conda-forge/win-64::pandoc-3.8.3-h57928b3_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main/win-64::ca-certificates-202~ --> conda-forge/noarch::ca-certificates-2025.11.12-h4c7d964_0
#   certifi            pkgs/main/win-64::certifi-2025.10.5-p~ --> conda-forge/noarch::certifi-2025.11.12-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-3.0.18-h543e019_0 --> conda-forge::openssl-3.6.0-h725018a_0
#
#
#
# Downloading and Extracting Packages: ...working...
# pandoc-3.8.3         | 25.5 MB   |            |   0%
#
# openssl-3.6.0        | 9.0 MB    |            |   0%
#
#
# certifi-2025.11.12   | 153 KB    |            |   0%
#
#
#
# ca-certificates-2025 | 149 KB    |            |   0%
# pandoc-3.8.3         | 25.5 MB   |            |   0%
#
# openssl-3.6.0        | 9.0 MB    |            |   0%
#
# openssl-3.6.0        | 9.0 MB    |            |   1%
# pandoc-3.8.3         | 25.5 MB   |            |   0%
# pandoc-3.8.3         | 25.5 MB   |            |   0%
#
# openssl-3.6.0        | 9.0 MB    | 1          |   1%
#
# openssl-3.6.0        | 9.0 MB    | 2          |   2%
# pandoc-3.8.3         | 25.5 MB   |            |   1%
# pandoc-3.8.3         | 25.5 MB   |            |   1%
#
# openssl-3.6.0        | 9.0 MB    | 2          |   3%
# pandoc-3.8.3         | 25.5 MB   | 1          |   1%
#
# openssl-3.6.0        | 9.0 MB    | 3          |   3%
# pandoc-3.8.3         | 25.5 MB   | 1          |   1%
#
# openssl-3.6.0        | 9.0 MB    | 4          |   5%
# pandoc-3.8.3         | 25.5 MB   | 1          |   2%
# pandoc-3.8.3         | 25.5 MB   | 2          |   2%
#
# openssl-3.6.0        | 9.0 MB    | 5          |   5%
# pandoc-3.8.3         | 25.5 MB   | 3          |   3%
#
# openssl-3.6.0        | 9.0 MB    | 5          |   6%
#
# openssl-3.6.0        | 9.0 MB    | 6          |   6%
#
# openssl-3.6.0        | 9.0 MB    | 7          |   7%
# pandoc-3.8.3         | 25.5 MB   | 3          |   3%
#
#
# certifi-2025.11.12   | 153 KB    | #          |  10%
# pandoc-3.8.3         | 25.5 MB   | 4          |   4%
#
#
# certifi-2025.11.12   | 153 KB    | ##         |  21%
#
# openssl-3.6.0        | 9.0 MB    | 7          |   8%
# pandoc-3.8.3         | 25.5 MB   | 4          |   4%
#
#
# certifi-2025.11.12   | 153 KB    | ###1       |  31%
#
# openssl-3.6.0        | 9.0 MB    | 9          |   9%
#
#
#
# ca-certificates-2025 | 149 KB    | #          |  11%
#
#
# certifi-2025.11.12   | 153 KB    | #####2     |  52%
# pandoc-3.8.3         | 25.5 MB   | 5          |   5%
#
#
# certifi-2025.11.12   | 153 KB    | ######2    |  63%
#
#
# certifi-2025.11.12   | 153 KB    | #######2   |  73%
#
# openssl-3.6.0        | 9.0 MB    | #          |  11%
# pandoc-3.8.3         | 25.5 MB   | 6          |   6%
#
#
# certifi-2025.11.12   | 153 KB    | ########3  |  83%
#
#
# certifi-2025.11.12   | 153 KB    | #########3 |  94%
# pandoc-3.8.3         | 25.5 MB   | 6          |   6%
# pandoc-3.8.3         | 25.5 MB   | 7          |   7%
#
# openssl-3.6.0        | 9.0 MB    | #3         |  13%
#
#
# certifi-2025.11.12   | 153 KB    | ########## | 100%
# pandoc-3.8.3         | 25.5 MB   | 7          |   8%
#
#
# certifi-2025.11.12   | 153 KB    | ########## | 100%
# pandoc-3.8.3         | 25.5 MB   | 8          |   8%
#
# openssl-3.6.0        | 9.0 MB    | #4         |  14%
# pandoc-3.8.3         | 25.5 MB   | 9          |   9%
#
# openssl-3.6.0        | 9.0 MB    | #6         |  16%
# pandoc-3.8.3         | 25.5 MB   | 9          |  10%
# pandoc-3.8.3         | 25.5 MB   | #          |  10%
#
# openssl-3.6.0        | 9.0 MB    | #7         |  17%
# pandoc-3.8.3         | 25.5 MB   | #          |  10%
# pandoc-3.8.3         | 25.5 MB   | #          |  11%
#
# openssl-3.6.0        | 9.0 MB    | #7         |  18%
# pandoc-3.8.3         | 25.5 MB   | #          |  11%
# pandoc-3.8.3         | 25.5 MB   | #1         |  12%
# pandoc-3.8.3         | 25.5 MB   | #2         |  12%
#
# openssl-3.6.0        | 9.0 MB    | ##         |  20%
# pandoc-3.8.3         | 25.5 MB   | #2         |  13%
#
# openssl-3.6.0        | 9.0 MB    | ##         |  21%
#
# openssl-3.6.0        | 9.0 MB    | ##3        |  24%
# pandoc-3.8.3         | 25.5 MB   | #3         |  13%
# pandoc-3.8.3         | 25.5 MB   | #3         |  14%
# pandoc-3.8.3         | 25.5 MB   | #4         |  14%
#
# openssl-3.6.0        | 9.0 MB    | ##4        |  25%
# pandoc-3.8.3         | 25.5 MB   | #4         |  15%
#
# openssl-3.6.0        | 9.0 MB    | ##5        |  26%
# pandoc-3.8.3         | 25.5 MB   | #4         |  15%
# pandoc-3.8.3         | 25.5 MB   | #5         |  15%
# pandoc-3.8.3         | 25.5 MB   | #5         |  16%
#
# openssl-3.6.0        | 9.0 MB    | ##6        |  26%
# pandoc-3.8.3         | 25.5 MB   | #5         |  16%
#
# openssl-3.6.0        | 9.0 MB    | ##6        |  27%
#
# openssl-3.6.0        | 9.0 MB    | ##7        |  28%
# pandoc-3.8.3         | 25.5 MB   | #6         |  16%
#
# openssl-3.6.0        | 9.0 MB    | ##8        |  28%
# pandoc-3.8.3         | 25.5 MB   | #6         |  17%
#
# openssl-3.6.0        | 9.0 MB    | ##8        |  29%
# pandoc-3.8.3         | 25.5 MB   | #7         |  17%
#
# openssl-3.6.0        | 9.0 MB    | ##9        |  29%
#
# openssl-3.6.0        | 9.0 MB    | ##9        |  30%
# pandoc-3.8.3         | 25.5 MB   | #7         |  18%
#
# openssl-3.6.0        | 9.0 MB    | ###        |  30%
# pandoc-3.8.3         | 25.5 MB   | #7         |  18%
#
# openssl-3.6.0        | 9.0 MB    | ###        |  31%
# pandoc-3.8.3         | 25.5 MB   | #8         |  18%
#
# openssl-3.6.0        | 9.0 MB    | ###1       |  31%
# pandoc-3.8.3         | 25.5 MB   | #8         |  18%
#
# openssl-3.6.0        | 9.0 MB    | ###1       |  31%
# pandoc-3.8.3         | 25.5 MB   | #8         |  19%
#
# openssl-3.6.0        | 9.0 MB    | ###1       |  32%
#
# openssl-3.6.0        | 9.0 MB    | ###2       |  32%
# pandoc-3.8.3         | 25.5 MB   | #8         |  19%
# pandoc-3.8.3         | 25.5 MB   | #8         |  19%
#
# openssl-3.6.0        | 9.0 MB    | ###2       |  33%
#
# openssl-3.6.0        | 9.0 MB    | ###3       |  33%
# pandoc-3.8.3         | 25.5 MB   | #9         |  19%
# pandoc-3.8.3         | 25.5 MB   | #9         |  19%
#
# openssl-3.6.0        | 9.0 MB    | ###3       |  34%
#
# openssl-3.6.0        | 9.0 MB    | ###4       |  34%
# pandoc-3.8.3         | 25.5 MB   | #9         |  20%
#
#
#
# ca-certificates-2025 | 149 KB    | ##1        |  21%
# pandoc-3.8.3         | 25.5 MB   | #9         |  20%
#
# openssl-3.6.0        | 9.0 MB    | ###4       |  35%
# pandoc-3.8.3         | 25.5 MB   | #9         |  20%
#
#
#
# ca-certificates-2025 | 149 KB    | ######4    |  64%
# pandoc-3.8.3         | 25.5 MB   | ##         |  20%
#
# openssl-3.6.0        | 9.0 MB    | ###4       |  35%
#
#
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
#
#
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
#
#
#
# ca-certificates-2025 | 149 KB    | ########## | 100%
#
# openssl-3.6.0        | 9.0 MB    | ###5       |  35%
# pandoc-3.8.3         | 25.5 MB   | ##         |  20%
#
# openssl-3.6.0        | 9.0 MB    | ###5       |  36%
# pandoc-3.8.3         | 25.5 MB   | ##         |  20%
#
# openssl-3.6.0        | 9.0 MB    | ###6       |  36%
# pandoc-3.8.3         | 25.5 MB   | ##         |  21%
#
# openssl-3.6.0        | 9.0 MB    | ###6       |  36%
#
# openssl-3.6.0        | 9.0 MB    | ###6       |  37%
#
# openssl-3.6.0        | 9.0 MB    | ###7       |  37%
# pandoc-3.8.3         | 25.5 MB   | ##1        |  21%
#
# openssl-3.6.0        | 9.0 MB    | ###7       |  37%
# pandoc-3.8.3         | 25.5 MB   | ##1        |  21%
# pandoc-3.8.3         | 25.5 MB   | ##1        |  22%
#
# openssl-3.6.0        | 9.0 MB    | ###7       |  38%
# pandoc-3.8.3         | 25.5 MB   | ##2        |  22%
#
# openssl-3.6.0        | 9.0 MB    | ###8       |  38%
# pandoc-3.8.3         | 25.5 MB   | ##2        |  22%
# pandoc-3.8.3         | 25.5 MB   | ##2        |  23%
#
# openssl-3.6.0        | 9.0 MB    | ###8       |  39%
#
# openssl-3.6.0        | 9.0 MB    | ###9       |  39%
# pandoc-3.8.3         | 25.5 MB   | ##2        |  23%
#
# openssl-3.6.0        | 9.0 MB    | ###9       |  40%
# pandoc-3.8.3         | 25.5 MB   | ##2        |  23%
# pandoc-3.8.3         | 25.5 MB   | ##3        |  23%
# pandoc-3.8.3         | 25.5 MB   | ##3        |  23%
#
# openssl-3.6.0        | 9.0 MB    | ####       |  40%
#
# openssl-3.6.0        | 9.0 MB    | ####       |  40%
# pandoc-3.8.3         | 25.5 MB   | ##3        |  24%
#
# openssl-3.6.0        | 9.0 MB    | ####       |  41%
#
# openssl-3.6.0        | 9.0 MB    | ####1      |  41%
# pandoc-3.8.3         | 25.5 MB   | ##3        |  24%
#
# openssl-3.6.0        | 9.0 MB    | ####1      |  42%
# pandoc-3.8.3         | 25.5 MB   | ##4        |  24%
#
# openssl-3.6.0        | 9.0 MB    | ####2      |  42%
# pandoc-3.8.3         | 25.5 MB   | ##4        |  24%
# pandoc-3.8.3         | 25.5 MB   | ##4        |  25%
# pandoc-3.8.3         | 25.5 MB   | ##5        |  25%
#
# openssl-3.6.0        | 9.0 MB    | ####2      |  43%
#
# openssl-3.6.0        | 9.0 MB    | ####3      |  44%
# pandoc-3.8.3         | 25.5 MB   | ##5        |  25%
# pandoc-3.8.3         | 25.5 MB   | ##5        |  25%
# pandoc-3.8.3         | 25.5 MB   | ##5        |  26%
# pandoc-3.8.3         | 25.5 MB   | ##5        |  26%
#
# openssl-3.6.0        | 9.0 MB    | ####4      |  44%
# pandoc-3.8.3         | 25.5 MB   | ##6        |  26%
# pandoc-3.8.3         | 25.5 MB   | ##6        |  26%
# pandoc-3.8.3         | 25.5 MB   | ##6        |  27%
# pandoc-3.8.3         | 25.5 MB   | ##6        |  27%
# pandoc-3.8.3         | 25.5 MB   | ##6        |  27%
#
# openssl-3.6.0        | 9.0 MB    | ####5      |  45%
# pandoc-3.8.3         | 25.5 MB   | ##7        |  27%
# pandoc-3.8.3         | 25.5 MB   | ##7        |  27%
#
# openssl-3.6.0        | 9.0 MB    | ####5      |  46%
# pandoc-3.8.3         | 25.5 MB   | ##7        |  27%
#
# openssl-3.6.0        | 9.0 MB    | ####6      |  47%
# pandoc-3.8.3         | 25.5 MB   | ##7        |  28%
#
# openssl-3.6.0        | 9.0 MB    | ####7      |  47%
# pandoc-3.8.3         | 25.5 MB   | ##7        |  28%
#
# openssl-3.6.0        | 9.0 MB    | ####7      |  48%
# pandoc-3.8.3         | 25.5 MB   | ##8        |  28%
# pandoc-3.8.3         | 25.5 MB   | ##8        |  28%
# pandoc-3.8.3         | 25.5 MB   | ##8        |  28%
#
# openssl-3.6.0        | 9.0 MB    | ####8      |  48%
# pandoc-3.8.3         | 25.5 MB   | ##8        |  29%
#
# openssl-3.6.0        | 9.0 MB    | ####8      |  49%
#
# openssl-3.6.0        | 9.0 MB    | ####9      |  49%
# pandoc-3.8.3         | 25.5 MB   | ##8        |  29%
# pandoc-3.8.3         | 25.5 MB   | ##9        |  29%
# pandoc-3.8.3         | 25.5 MB   | ##9        |  29%
#
# openssl-3.6.0        | 9.0 MB    | ####9      |  50%
#
# openssl-3.6.0        | 9.0 MB    | ####9      |  50%
# pandoc-3.8.3         | 25.5 MB   | ##9        |  29%
#
# openssl-3.6.0        | 9.0 MB    | #####      |  50%
# pandoc-3.8.3         | 25.5 MB   | ##9        |  30%
# pandoc-3.8.3         | 25.5 MB   | ##9        |  30%
# pandoc-3.8.3         | 25.5 MB   | ###        |  30%
#
# openssl-3.6.0        | 9.0 MB    | #####      |  51%
#
# openssl-3.6.0        | 9.0 MB    | #####1     |  52%
# pandoc-3.8.3         | 25.5 MB   | ###        |  30%
# pandoc-3.8.3         | 25.5 MB   | ###        |  30%
#
# openssl-3.6.0        | 9.0 MB    | #####2     |  52%
# pandoc-3.8.3         | 25.5 MB   | ###        |  31%
#
# openssl-3.6.0        | 9.0 MB    | #####2     |  52%
# pandoc-3.8.3         | 25.5 MB   | ###        |  31%
# pandoc-3.8.3         | 25.5 MB   | ###        |  31%
#
# openssl-3.6.0        | 9.0 MB    | #####2     |  53%
#
# openssl-3.6.0        | 9.0 MB    | #####3     |  53%
#
# openssl-3.6.0        | 9.0 MB    | #####3     |  54%
# pandoc-3.8.3         | 25.5 MB   | ###1       |  31%
# pandoc-3.8.3         | 25.5 MB   | ###1       |  31%
#
# openssl-3.6.0        | 9.0 MB    | #####4     |  54%
# pandoc-3.8.3         | 25.5 MB   | ###1       |  32%
# pandoc-3.8.3         | 25.5 MB   | ###1       |  32%
#
# openssl-3.6.0        | 9.0 MB    | #####4     |  55%
#
# openssl-3.6.0        | 9.0 MB    | #####5     |  55%
# pandoc-3.8.3         | 25.5 MB   | ###1       |  32%
# pandoc-3.8.3         | 25.5 MB   | ###2       |  32%
# pandoc-3.8.3         | 25.5 MB   | ###2       |  32%
#
# openssl-3.6.0        | 9.0 MB    | #####5     |  56%
# pandoc-3.8.3         | 25.5 MB   | ###2       |  33%
#
# openssl-3.6.0        | 9.0 MB    | #####6     |  56%
# pandoc-3.8.3         | 25.5 MB   | ###2       |  33%
#
# openssl-3.6.0        | 9.0 MB    | #####6     |  57%
# pandoc-3.8.3         | 25.5 MB   | ###2       |  33%
#
# openssl-3.6.0        | 9.0 MB    | #####7     |  57%
# pandoc-3.8.3         | 25.5 MB   | ###3       |  33%
#
# openssl-3.6.0        | 9.0 MB    | #####7     |  58%
# pandoc-3.8.3         | 25.5 MB   | ###3       |  33%
# pandoc-3.8.3         | 25.5 MB   | ###3       |  34%
#
# openssl-3.6.0        | 9.0 MB    | #####8     |  58%
# pandoc-3.8.3         | 25.5 MB   | ###3       |  34%
#
# openssl-3.6.0        | 9.0 MB    | #####8     |  59%
#
# openssl-3.6.0        | 9.0 MB    | #####9     |  59%
# pandoc-3.8.3         | 25.5 MB   | ###4       |  34%
# pandoc-3.8.3         | 25.5 MB   | ###4       |  34%
#
# openssl-3.6.0        | 9.0 MB    | ######     |  60%
#
# openssl-3.6.0        | 9.0 MB    | ######     |  61%
# pandoc-3.8.3         | 25.5 MB   | ###4       |  35%
# pandoc-3.8.3         | 25.5 MB   | ###4       |  35%
#
# openssl-3.6.0        | 9.0 MB    | ######     |  61%
#
# openssl-3.6.0        | 9.0 MB    | ######1    |  61%
# pandoc-3.8.3         | 25.5 MB   | ###4       |  35%
#
# openssl-3.6.0        | 9.0 MB    | ######1    |  62%
# pandoc-3.8.3         | 25.5 MB   | ###5       |  35%
# pandoc-3.8.3         | 25.5 MB   | ###5       |  35%
#
# openssl-3.6.0        | 9.0 MB    | ######2    |  62%
# pandoc-3.8.3         | 25.5 MB   | ###5       |  36%
#
# openssl-3.6.0        | 9.0 MB    | ######2    |  62%
# pandoc-3.8.3         | 25.5 MB   | ###5       |  36%
#
# openssl-3.6.0        | 9.0 MB    | ######2    |  63%
#
# openssl-3.6.0        | 9.0 MB    | ######3    |  64%
# pandoc-3.8.3         | 25.5 MB   | ###6       |  36%
# pandoc-3.8.3         | 25.5 MB   | ###6       |  36%
#
# openssl-3.6.0        | 9.0 MB    | ######4    |  64%
# pandoc-3.8.3         | 25.5 MB   | ###6       |  37%
# pandoc-3.8.3         | 25.5 MB   | ###6       |  37%
# pandoc-3.8.3         | 25.5 MB   | ###7       |  37%
#
# openssl-3.6.0        | 9.0 MB    | ######4    |  65%
#
# openssl-3.6.0        | 9.0 MB    | ######6    |  66%
# pandoc-3.8.3         | 25.5 MB   | ###7       |  37%
#
# openssl-3.6.0        | 9.0 MB    | ######7    |  67%
# pandoc-3.8.3         | 25.5 MB   | ###7       |  38%
# pandoc-3.8.3         | 25.5 MB   | ###7       |  38%
#
# openssl-3.6.0        | 9.0 MB    | ######7    |  68%
# pandoc-3.8.3         | 25.5 MB   | ###8       |  38%
#
# openssl-3.6.0        | 9.0 MB    | ######8    |  69%
# pandoc-3.8.3         | 25.5 MB   | ###8       |  38%
#
# openssl-3.6.0        | 9.0 MB    | ######9    |  70%
# pandoc-3.8.3         | 25.5 MB   | ###8       |  39%
#
# openssl-3.6.0        | 9.0 MB    | #######    |  70%
# pandoc-3.8.3         | 25.5 MB   | ###8       |  39%
# pandoc-3.8.3         | 25.5 MB   | ###9       |  39%
# pandoc-3.8.3         | 25.5 MB   | ###9       |  39%
#
# openssl-3.6.0        | 9.0 MB    | #######    |  71%
#
# openssl-3.6.0        | 9.0 MB    | #######2   |  72%
# pandoc-3.8.3         | 25.5 MB   | ###9       |  40%
# pandoc-3.8.3         | 25.5 MB   | ####       |  40%
# pandoc-3.8.3         | 25.5 MB   | ####       |  40%
#
# openssl-3.6.0        | 9.0 MB    | #######3   |  73%
# pandoc-3.8.3         | 25.5 MB   | ####       |  41%
#
# openssl-3.6.0        | 9.0 MB    | #######3   |  74%
# pandoc-3.8.3         | 25.5 MB   | ####       |  41%
#
# openssl-3.6.0        | 9.0 MB    | #######4   |  74%
#
# openssl-3.6.0        | 9.0 MB    | #######5   |  75%
# pandoc-3.8.3         | 25.5 MB   | ####1      |  41%
#
# openssl-3.6.0        | 9.0 MB    | #######5   |  76%
# pandoc-3.8.3         | 25.5 MB   | ####1      |  41%
#
# openssl-3.6.0        | 9.0 MB    | #######6   |  77%
# pandoc-3.8.3         | 25.5 MB   | ####1      |  41%
# pandoc-3.8.3         | 25.5 MB   | ####1      |  42%
#
# openssl-3.6.0        | 9.0 MB    | #######7   |  77%
# pandoc-3.8.3         | 25.5 MB   | ####1      |  42%
# pandoc-3.8.3         | 25.5 MB   | ####2      |  42%
#
# openssl-3.6.0        | 9.0 MB    | #######7   |  78%
# pandoc-3.8.3         | 25.5 MB   | ####2      |  42%
#
# openssl-3.6.0        | 9.0 MB    | #######7   |  78%
# pandoc-3.8.3         | 25.5 MB   | ####2      |  43%
#
# openssl-3.6.0        | 9.0 MB    | #######8   |  79%
#
# openssl-3.6.0        | 9.0 MB    | #######9   |  79%
# pandoc-3.8.3         | 25.5 MB   | ####2      |  43%
#
# openssl-3.6.0        | 9.0 MB    | #######9   |  80%
# pandoc-3.8.3         | 25.5 MB   | ####3      |  43%
# pandoc-3.8.3         | 25.5 MB   | ####3      |  43%
#
# openssl-3.6.0        | 9.0 MB    | ########   |  80%
#
# openssl-3.6.0        | 9.0 MB    | ########   |  81%
# pandoc-3.8.3         | 25.5 MB   | ####3      |  44%
# pandoc-3.8.3         | 25.5 MB   | ####3      |  44%
#
# openssl-3.6.0        | 9.0 MB    | ########1  |  81%
# pandoc-3.8.3         | 25.5 MB   | ####3      |  44%
#
# openssl-3.6.0        | 9.0 MB    | ########1  |  82%
# pandoc-3.8.3         | 25.5 MB   | ####4      |  44%
# pandoc-3.8.3         | 25.5 MB   | ####4      |  44%
#
# openssl-3.6.0        | 9.0 MB    | ########2  |  83%
# pandoc-3.8.3         | 25.5 MB   | ####4      |  45%
#
# openssl-3.6.0        | 9.0 MB    | ########3  |  83%
#
# openssl-3.6.0        | 9.0 MB    | ########3  |  84%
# pandoc-3.8.3         | 25.5 MB   | ####4      |  45%
# pandoc-3.8.3         | 25.5 MB   | ####5      |  45%
#
# openssl-3.6.0        | 9.0 MB    | ########4  |  85%
# pandoc-3.8.3         | 25.5 MB   | ####5      |  45%
#
# openssl-3.6.0        | 9.0 MB    | ########5  |  85%
# pandoc-3.8.3         | 25.5 MB   | ####5      |  46%
#
# openssl-3.6.0        | 9.0 MB    | ########6  |  86%
# pandoc-3.8.3         | 25.5 MB   | ####5      |  46%
# pandoc-3.8.3         | 25.5 MB   | ####5      |  46%
#
# openssl-3.6.0        | 9.0 MB    | ########6  |  87%
# pandoc-3.8.3         | 25.5 MB   | ####6      |  46%
#
# openssl-3.6.0        | 9.0 MB    | ########7  |  88%
# pandoc-3.8.3         | 25.5 MB   | ####6      |  47%
# pandoc-3.8.3         | 25.5 MB   | ####7      |  47%
#
# openssl-3.6.0        | 9.0 MB    | ########8  |  89%
#
# openssl-3.6.0        | 9.0 MB    | ########9  |  89%
#
# openssl-3.6.0        | 9.0 MB    | ########9  |  90%
# pandoc-3.8.3         | 25.5 MB   | ####7      |  47%
# pandoc-3.8.3         | 25.5 MB   | ####7      |  48%
#
# openssl-3.6.0        | 9.0 MB    | #########  |  90%
#
# openssl-3.6.0        | 9.0 MB    | #########  |  91%
# pandoc-3.8.3         | 25.5 MB   | ####8      |  48%
#
# openssl-3.6.0        | 9.0 MB    | #########1 |  91%
#
# openssl-3.6.0        | 9.0 MB    | #########1 |  91%
# pandoc-3.8.3         | 25.5 MB   | ####8      |  48%
# pandoc-3.8.3         | 25.5 MB   | ####8      |  49%
#
# openssl-3.6.0        | 9.0 MB    | #########2 |  92%
#
# openssl-3.6.0        | 9.0 MB    | #########3 |  93%
# pandoc-3.8.3         | 25.5 MB   | ####9      |  49%
#
# openssl-3.6.0        | 9.0 MB    | #########3 |  94%
# pandoc-3.8.3         | 25.5 MB   | ####9      |  49%
#
# openssl-3.6.0        | 9.0 MB    | #########4 |  94%
# pandoc-3.8.3         | 25.5 MB   | ####9      |  50%
# pandoc-3.8.3         | 25.5 MB   | ####9      |  50%
#
# openssl-3.6.0        | 9.0 MB    | #########4 |  95%
# pandoc-3.8.3         | 25.5 MB   | #####      |  50%
#
# openssl-3.6.0        | 9.0 MB    | #########5 |  95%
# pandoc-3.8.3         | 25.5 MB   | #####      |  50%
#
# openssl-3.6.0        | 9.0 MB    | #########5 |  96%
# pandoc-3.8.3         | 25.5 MB   | #####      |  50%
# pandoc-3.8.3         | 25.5 MB   | #####      |  51%
# pandoc-3.8.3         | 25.5 MB   | #####      |  51%
#
# openssl-3.6.0        | 9.0 MB    | #########6 |  96%
# pandoc-3.8.3         | 25.5 MB   | #####1     |  51%
#
# openssl-3.6.0        | 9.0 MB    | #########6 |  97%
# pandoc-3.8.3         | 25.5 MB   | #####1     |  51%
#
# openssl-3.6.0        | 9.0 MB    | #########7 |  97%
# pandoc-3.8.3         | 25.5 MB   | #####1     |  52%
# pandoc-3.8.3         | 25.5 MB   | #####1     |  52%
#
# openssl-3.6.0        | 9.0 MB    | #########8 |  98%
#
# openssl-3.6.0        | 9.0 MB    | #########8 |  98%
# pandoc-3.8.3         | 25.5 MB   | #####2     |  52%
#
# openssl-3.6.0        | 9.0 MB    | #########8 |  99%
# pandoc-3.8.3         | 25.5 MB   | #####2     |  52%
#
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
# pandoc-3.8.3         | 25.5 MB   | #####3     |  53%
# pandoc-3.8.3         | 25.5 MB   | #####3     |  54%
# pandoc-3.8.3         | 25.5 MB   | #####3     |  54%
# pandoc-3.8.3         | 25.5 MB   | #####4     |  54%
# pandoc-3.8.3         | 25.5 MB   | #####4     |  54%
# pandoc-3.8.3         | 25.5 MB   | #####4     |  55%
# pandoc-3.8.3         | 25.5 MB   | #####4     |  55%
# pandoc-3.8.3         | 25.5 MB   | #####5     |  55%
# pandoc-3.8.3         | 25.5 MB   | #####5     |  56%
# pandoc-3.8.3         | 25.5 MB   | #####5     |  56%
# pandoc-3.8.3         | 25.5 MB   | #####6     |  56%
# pandoc-3.8.3         | 25.5 MB   | #####6     |  56%
# pandoc-3.8.3         | 25.5 MB   | #####6     |  57%
# pandoc-3.8.3         | 25.5 MB   | #####6     |  57%
# pandoc-3.8.3         | 25.5 MB   | #####7     |  57%
# pandoc-3.8.3         | 25.5 MB   | #####7     |  58%
# pandoc-3.8.3         | 25.5 MB   | #####7     |  58%
# pandoc-3.8.3         | 25.5 MB   | #####8     |  58%
# pandoc-3.8.3         | 25.5 MB   | #####8     |  59%
# pandoc-3.8.3         | 25.5 MB   | #####9     |  59%
#
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
#
# openssl-3.6.0        | 9.0 MB    | ########## | 100%
# pandoc-3.8.3         | 25.5 MB   | #####9     |  59%
# pandoc-3.8.3         | 25.5 MB   | #####9     |  60%
# pandoc-3.8.3         | 25.5 MB   | ######     |  60%
# pandoc-3.8.3         | 25.5 MB   | ######     |  60%
# pandoc-3.8.3         | 25.5 MB   | ######     |  61%
# pandoc-3.8.3         | 25.5 MB   | ######1    |  61%
# pandoc-3.8.3         | 25.5 MB   | ######1    |  62%
# pandoc-3.8.3         | 25.5 MB   | ######2    |  62%
# pandoc-3.8.3         | 25.5 MB   | ######2    |  62%
# pandoc-3.8.3         | 25.5 MB   | ######2    |  63%
# pandoc-3.8.3         | 25.5 MB   | ######3    |  63%
# pandoc-3.8.3         | 25.5 MB   | ######3    |  64%
# pandoc-3.8.3         | 25.5 MB   | ######3    |  64%
# pandoc-3.8.3         | 25.5 MB   | ######4    |  64%
# pandoc-3.8.3         | 25.5 MB   | ######4    |  64%
# pandoc-3.8.3         | 25.5 MB   | ######4    |  65%
# pandoc-3.8.3         | 25.5 MB   | ######5    |  65%
# pandoc-3.8.3         | 25.5 MB   | ######5    |  65%
# pandoc-3.8.3         | 25.5 MB   | ######5    |  66%
# pandoc-3.8.3         | 25.5 MB   | ######6    |  66%
# pandoc-3.8.3         | 25.5 MB   | ######6    |  67%
# pandoc-3.8.3         | 25.5 MB   | ######6    |  67%
# pandoc-3.8.3         | 25.5 MB   | ######7    |  67%
# pandoc-3.8.3         | 25.5 MB   | ######7    |  68%
# pandoc-3.8.3         | 25.5 MB   | ######8    |  68%
# pandoc-3.8.3         | 25.5 MB   | ######8    |  69%
# pandoc-3.8.3         | 25.5 MB   | ######8    |  69%
# pandoc-3.8.3         | 25.5 MB   | ######9    |  69%
# pandoc-3.8.3         | 25.5 MB   | ######9    |  70%
# pandoc-3.8.3         | 25.5 MB   | #######    |  70%
# pandoc-3.8.3         | 25.5 MB   | #######    |  71%
# pandoc-3.8.3         | 25.5 MB   | #######1   |  71%
# pandoc-3.8.3         | 25.5 MB   | #######1   |  72%
# pandoc-3.8.3         | 25.5 MB   | #######2   |  72%
# pandoc-3.8.3         | 25.5 MB   | #######2   |  72%
# pandoc-3.8.3         | 25.5 MB   | #######2   |  73%
# pandoc-3.8.3         | 25.5 MB   | #######3   |  73%
# pandoc-3.8.3         | 25.5 MB   | #######3   |  74%
# pandoc-3.8.3         | 25.5 MB   | #######4   |  74%
# pandoc-3.8.3         | 25.5 MB   | #######4   |  75%
# pandoc-3.8.3         | 25.5 MB   | #######5   |  75%
# pandoc-3.8.3         | 25.5 MB   | #######5   |  76%
# pandoc-3.8.3         | 25.5 MB   | #######6   |  76%
# pandoc-3.8.3         | 25.5 MB   | #######6   |  76%
# pandoc-3.8.3         | 25.5 MB   | #######6   |  77%
# pandoc-3.8.3         | 25.5 MB   | #######7   |  77%
# pandoc-3.8.3         | 25.5 MB   | #######7   |  78%
# pandoc-3.8.3         | 25.5 MB   | #######7   |  78%
# pandoc-3.8.3         | 25.5 MB   | #######8   |  78%
# pandoc-3.8.3         | 25.5 MB   | #######8   |  79%
# pandoc-3.8.3         | 25.5 MB   | #######8   |  79%
# pandoc-3.8.3         | 25.5 MB   | #######9   |  79%
# pandoc-3.8.3         | 25.5 MB   | #######9   |  80%
# pandoc-3.8.3         | 25.5 MB   | #######9   |  80%
# pandoc-3.8.3         | 25.5 MB   | ########   |  80%
# pandoc-3.8.3         | 25.5 MB   | ########   |  81%
# pandoc-3.8.3         | 25.5 MB   | ########   |  81%
# pandoc-3.8.3         | 25.5 MB   | ########1  |  81%
# pandoc-3.8.3         | 25.5 MB   | ########1  |  82%
# pandoc-3.8.3         | 25.5 MB   | ########2  |  82%
# pandoc-3.8.3         | 25.5 MB   | ########2  |  83%
# pandoc-3.8.3         | 25.5 MB   | ########2  |  83%
# pandoc-3.8.3         | 25.5 MB   | ########3  |  83%
# pandoc-3.8.3         | 25.5 MB   | ########3  |  84%
# pandoc-3.8.3         | 25.5 MB   | ########4  |  84%
# pandoc-3.8.3         | 25.5 MB   | ########4  |  85%
# pandoc-3.8.3         | 25.5 MB   | ########4  |  85%
# pandoc-3.8.3         | 25.5 MB   | ########5  |  85%
# pandoc-3.8.3         | 25.5 MB   | ########5  |  86%
# pandoc-3.8.3         | 25.5 MB   | ########5  |  86%
# pandoc-3.8.3         | 25.5 MB   | ########6  |  86%
# pandoc-3.8.3         | 25.5 MB   | ########6  |  87%
# pandoc-3.8.3         | 25.5 MB   | ########7  |  87%
# pandoc-3.8.3         | 25.5 MB   | ########7  |  87%
# pandoc-3.8.3         | 25.5 MB   | ########7  |  88%
# pandoc-3.8.3         | 25.5 MB   | ########7  |  88%
# pandoc-3.8.3         | 25.5 MB   | ########8  |  88%
# pandoc-3.8.3         | 25.5 MB   | ########8  |  89%
# pandoc-3.8.3         | 25.5 MB   | ########8  |  89%
# pandoc-3.8.3         | 25.5 MB   | ########9  |  89%
# pandoc-3.8.3         | 25.5 MB   | ########9  |  90%
# pandoc-3.8.3         | 25.5 MB   | ########9  |  90%
# pandoc-3.8.3         | 25.5 MB   | #########  |  90%
# pandoc-3.8.3         | 25.5 MB   | #########  |  91%
# pandoc-3.8.3         | 25.5 MB   | #########1 |  91%
# pandoc-3.8.3         | 25.5 MB   | #########1 |  92%
# pandoc-3.8.3         | 25.5 MB   | #########2 |  92%
# pandoc-3.8.3         | 25.5 MB   | #########2 |  92%
# pandoc-3.8.3         | 25.5 MB   | #########2 |  93%
# pandoc-3.8.3         | 25.5 MB   | #########3 |  93%
# pandoc-3.8.3         | 25.5 MB   | #########3 |  94%
# pandoc-3.8.3         | 25.5 MB   | #########4 |  94%
# pandoc-3.8.3         | 25.5 MB   | #########4 |  95%
# pandoc-3.8.3         | 25.5 MB   | #########4 |  95%
# pandoc-3.8.3         | 25.5 MB   | #########5 |  95%
# pandoc-3.8.3         | 25.5 MB   | #########5 |  96%
# pandoc-3.8.3         | 25.5 MB   | #########6 |  96%
# pandoc-3.8.3         | 25.5 MB   | #########6 |  97%
# pandoc-3.8.3         | 25.5 MB   | #########6 |  97%
# pandoc-3.8.3         | 25.5 MB   | #########7 |  97%
# pandoc-3.8.3         | 25.5 MB   | #########7 |  98%
# pandoc-3.8.3         | 25.5 MB   | #########7 |  98%
# pandoc-3.8.3         | 25.5 MB   | #########8 |  98%
# pandoc-3.8.3         | 25.5 MB   | #########8 |  98%
# pandoc-3.8.3         | 25.5 MB   | #########8 |  99%
# pandoc-3.8.3         | 25.5 MB   | #########9 |  99%
# pandoc-3.8.3         | 25.5 MB   | #########9 | 100%
# pandoc-3.8.3         | 25.5 MB   | ########## | 100%
# pandoc-3.8.3         | 25.5 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
conda install nbconvert
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\marvin\anaconda3\envs\DSP11-CPE3A
#
#   added / updated specs:
#     - nbconvert
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       haa95532_0         125 KB
#     nbconvert-7.16.6           |  py312haa95532_0           9 KB
#     nbconvert-pandoc-7.16.6    |  py312haa95532_0           9 KB
#     ------------------------------------------------------------
#                                            Total:         143 KB
#
# The following NEW packages will be INSTALLED:
#
#   nbconvert          pkgs/main/win-64::nbconvert-7.16.6-py312haa95532_0
#   nbconvert-pandoc   pkgs/main/win-64::nbconvert-pandoc-7.16.6-py312haa95532_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/noarch::ca-certificates-2~ --> pkgs/main/win-64::ca-certificates-2025.12.2-haa95532_0
#
#
#
# Downloading and Extracting Packages: ...working...
# ca-certificates-2025 | 125 KB    |            |   0%
#
# nbconvert-pandoc-7.1 | 9 KB      |            |   0%
#
#
# nbconvert-7.16.6     | 9 KB      |            |   0%
# ca-certificates-2025 | 125 KB    | #2         |  13%
#
# nbconvert-pandoc-7.1 | 9 KB      | ########## | 100%
#
# nbconvert-pandoc-7.1 | 9 KB      | ########## | 100%
# ca-certificates-2025 | 125 KB    | #####1     |  51%
#
# nbconvert-pandoc-7.1 | 9 KB      | ########## | 100%
# ca-certificates-2025 | 125 KB    | ########## | 100%
# ca-certificates-2025 | 125 KB    | ########## | 100%
# ca-certificates-2025 | 125 KB    | ########## | 100%
#
#
# nbconvert-7.16.6     | 9 KB      | ########## | 100%
#
#
# nbconvert-7.16.6     | 9 KB      | ########## | 100%
#
#
# nbconvert-7.16.6     | 9 KB      | ########## | 100%
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.5.1
#     latest version: 25.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
pip install SciencePlots
# Out:
# Requirement already satisfied: SciencePlots in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (2.2.0)
# Requirement already satisfied: matplotlib in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from SciencePlots) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from matplotlib->SciencePlots) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\marvin\anaconda3\envs\dsp11-cpe3a\lib\site-packages (from python-dateutil>=2.7->matplotlib->SciencePlots) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import scienceplots
import numpy as np
import matplotlib.pyplot as plt

# If the line below is giving you compiler errors, comment it out.
plt.style.use(['science', 'notebook', 'grid'])

# %%
frameSize = 1024

impulse = np.zeros(frameSize)
impulse[0] = 1;

plt.plot(impulse, 'bo-')
plt.xlabel('Sample count')
plt.ylabel('Amplitude')
plt.xlim(-0.5, 10)
plt.title("Impulse signal (Time domain)")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Let's listen to what the impulse signal sounds like

# %%
from IPython.display import Audio

sampleRate = 44100
audio = Audio(data=impulse, rate=sampleRate)
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Frequency analysis of impulse signal
#
# Performing Fourier analysis (FFT) we can see the frequency representation of the impulse signal which reveals that all represetnable frequencies are present within this impulse signal

# %%
from scipy.fftpack import fft

spectrum = fft(impulse)

x = np.linspace(0, spectrum.size * sampleRate / frameSize / 2 , spectrum.size//2)
y = np.abs(spectrum)[:spectrum.size//2]
plt.plot(x, y)
plt.xscale('log')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.title('Impulse signal (Frequency domain)')
plt.show()

# %% [markdown]
# Why do impulse signals contain all possible sinusoids? Let's try and think about it the other way around. What would a signal look like when you add all possible sinusoids together?
#
# ### Sum of cosines
#
# Let's take a sample rate of 400. And let's add sinusoids together starting from a sinusoid of frequency 1, all the way to a sinusoid of frequency 200 (Nyquist frequency). What do you think we'd get?

# %%
sampleRate = 400
freq = 200

arr = np.linspace(0, freq, sampleRate)
combination = np.zeros(sampleRate)
for f in range(1, freq):
    combination += np.cos(2 * np.pi * f * arr)
combination /= freq

plt.plot(combination[:combination.size//2], 'o-')
plt.xlabel('Sample count')
plt.ylabel('Amplitude')
#plt.xlim(-0.5, 10)
plt.title("Combination of " + str(freq) + " cosines")
plt.show()

# %% [markdown]
# ### An alternate approach: Sinc function
#
# Here's an alternative way of taking a function in continuous time and converting it into an impulse signal in discrete time. The <b>sinc function</b>. The normalized form of the sinc function (which is the default form in NumPy) can be used, and when plotted on integral sample points, we get an impulse signal.

# %%
arr = np.arange(-200, 200, 1)
sincNormalized = np.sinc(arr)
sincUnnormalized = np.sinc(arr/np.pi)
plt.plot(sincUnnormalized, 'ro-', label='Unnormalized')
plt.plot(sincNormalized, 'bo-', label='Normalized')
plt.xlim(175,225)
plt.show
plt.legend()
